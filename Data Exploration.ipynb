# %%
import pandas as pd

# %%
df_bookings = pd.read_csv(r"C:\Users\pawar\Downloads\fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2027-04-22      1/5/2022
# 1        May012216558RT12        16558   1930-04-22      1/5/2022
# 2        May012216558RT13        16558   2028-04-22      1/5/2022
# 3        May012216558RT14        16558   2028-04-22      1/5/2022
# 4        May012216558RT15        16558   2027-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2029-07-22    1931-07-22
# 134586   Jul312217564RT47        17564   1930-07-22    1931-07-22
# 134587   Jul312217564RT48        17564   1930-07-22    1931-07-22
# 134588   Jul312217564RT49        17564   2029-07-22    1931-07-22
# 134589  Jul312217564RT410        17564   1931-07-22    1931-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2027-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558   1930-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558   2028-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558   2028-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_date = pd.read_csv(r"C:\Users\pawar\Downloads\dim_date.csv")
df_hotels = pd.read_csv(r"C:\Users\pawar\Downloads\dim_hotels.csv")
df_rooms= pd.read_csv(r"C:\Users\pawar\Downloads\dim_rooms.csv")
df_agg_bookings = pd.read_csv(r"C:\Users\pawar\Downloads\fact_aggregrated_books.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0

# %%
df_agg_bookings.property_id.unique
# Out:
# <bound method Series.unique of 0       16559
# 1       19562
# 2       19563
# 3       17558
# 4       16558
#         ...
# 9195    16563
# 9196    16559
# 9197    17558
# 9198    19563
# 9199    17561
# Name: property_id, Length: 9200, dtype: int64>

# %%
df_agg_bookings.property_id.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       16559
# 1       19562
# 2       19563
# 3       17558
# 4       16558
#         ...
# 9195    16563
# 9196    16559
# 9197    17558
# 9198    19563
# 9199    17561
# Name: property_id, Length: 9200, dtype: int64>

# %%
df_agg_bookings.capacity.max()
# Out:
# np.float64(50.0)

# %%
df_rooms.head(4)
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_agg_bookings.property_id.max()
# Out:
# np.int64(19563)

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2027-04-22      1/5/2022
# 3        May012216558RT14        16558   2028-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560   2019-07-22    2020-07-22
# 134586   Jul312217564RT47        17564   1930-07-22    1931-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings[df_bookings.no_guests>0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558   1930-04-22      1/5/2022
# 2        May012216558RT13        16558   2028-04-22      1/5/2022
# 4        May012216558RT15        16558   2027-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558   2028-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564   1930-07-22    1931-07-22
# 134585   Jul312217564RT46        17564   2029-07-22    1931-07-22
# 134587   Jul312217564RT48        17564   1930-07-22    1931-07-22
# 134588   Jul312217564RT49        17564   2029-07-22    1931-07-22
# 134589  Jul312217564RT410        17564   1931-07-22    1931-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
avg, std
# Out:
# (np.float64(15378.05412734973), np.float64(93036.03867095453))

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(294486.17014021333)

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# np.float64(-263730.06188551383)

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.shape
# Out:
# (134585, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134585.000000
# mean      12696.095025
# std        6928.058192
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() +3*df_bookings.revenue_realized
higher_limit
# Out:
# 0          42726.095025
# 1          23616.095025
# 3          23616.095025
# 4          45456.095025
# 5          39996.095025
#               ...
# 134585    109596.095025
# 134586    128976.095025
# 134587     51456.095025
# 134588    109596.095025
# 134589     51456.095025
# Name: revenue_realized, Length: 134585, dtype: float64

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16073.000000
# mean     23440.103652
# std       9048.865206
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77905
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134585.000000  134582.000000   56680.000000      134585.000000
# mean    18061.161831       2.036142       3.619001       14916.018167
# std      1093.044668       1.034848       1.235022        6452.846504
# min     16558.000000     -17.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134585.000000
# mean       12696.095025
# std         6928.058192
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings = pd.read_csv(r"C:\Users\pawar\Downloads\fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2027-04-22      1/5/2022
# 1        May012216558RT12        16558   1930-04-22      1/5/2022
# 2        May012216558RT13        16558   2028-04-22      1/5/2022
# 3        May012216558RT14        16558   2028-04-22      1/5/2022
# 4        May012216558RT15        16558   2027-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2029-07-22    1931-07-22
# 134586   Jul312217564RT47        17564   1930-07-22    1931-07-22
# 134587   Jul312217564RT48        17564   1930-07-22    1931-07-22
# 134588   Jul312217564RT49        17564   2029-07-22    1931-07-22
# 134589  Jul312217564RT410        17564   1931-07-22    1931-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.median()
# Out:
# (np.float64(15378.05412734973), np.float64(13500.0))

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0
# 4        16558     01-May-22           RT1                   18      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x: round(x*100,2))
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %% [markdown]
# **What is an average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# 9196    72.22     RT4  Presidential
# 9197    50.00     RT4  Presidential
# 9198    50.00     RT4  Presidential
# 9199    75.00     RT4  Presidential

# %%
df.groupby("room_class")["occ_pct"].mean().round()
# Out:
# room_class
# Elite           58.0
# Premium         58.0
# Presidential    59.0
# Standard        58.0
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id", axis=1, inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %% [markdown]
# **Print average occupancy rate per city**

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on="property_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0
# 4        16558     01-May-22           RT1                   18      19.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai
# 4    94.74   Standard   Atliq Grands    Luxury      Delhi

# %%
df.groupby("city")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **When was the occupancy better? Weekday or Weekend?**

# %%
df_date = pd.read_csv(r"C:\Users\pawar\Downloads\dim_date.csv")

# %%
df_date
# Out:
#     date  mmm yy week no  day_type
# 0   date  22-May    W 19   weekend
# 1   date  22-May    W 19  weekeday
# 2   date  22-May    W 19  weekeday
# 3   date  22-May    W 19  weekeday
# 4   date  22-May    W 19  weekeday
# ..   ...     ...     ...       ...
# 87  date  22-Jul    W 31  weekeday
# 88  date  22-Jul    W 31  weekeday
# 89  date  22-Jul    W 31  weekeday
# 90  date  22-Jul    W 31   weekend
# 91  date  22-Jul    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore

# %%
df["mmm yy"] = pd.to_datetime(df["check_in_date"], format="%d-%b-%y").dt.strftime("%y-%b")
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     01-May-22           RT1                   25      30.0
# 1           19562     01-May-22           RT1                   28      30.0
# 2           19563     01-May-22           RT1                   23      30.0
# 3           17558     01-May-22           RT1                   30      19.0
# 4           16558     01-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# ...

# %%
# Convert check_in_date to datetime
df["check_in_date"] = pd.to_datetime(df["check_in_date"], format="%d-%b-%y")

# Make month-year key
df["mmm yy"] = df["check_in_date"].dt.strftime("%y-%b")

# Merge using month-year
final_df = pd.merge(df, df_date, on="mmm yy", how="left")

final_df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25      30.0
# 1        16559    2022-05-01           RT1                   25      30.0
# 2        16559    2022-05-01           RT1                   25      30.0
# 3        16559    2022-05-01           RT1                   25      30.0
# 4        16559    2022-05-01           RT1                   25      30.0
#
#    occ_pct room_class  property_name category    city  mmm yy  date week no  \
# 0    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 1    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 2    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 3    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 4    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
#
#    day_type
# 0   weekend
# 1  weekeday
# 2  weekeday
# ...

# %%
final_df["mmm yy"].unique()
# Out:
# array(['22-May', '22-Jun', '22-Jul'], dtype=object)

# %%
 df_june_22 = df[df["mmm yy"] == "22-Jun"]
df_june_22.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 3100        16559    2022-06-01           RT1                   14      30.0
# 3101        18560    2022-06-01           RT1                   18      30.0
# 3102        19562    2022-06-01           RT1                   18      30.0
#
#       occ_pct room_class  property_name  category       city  mmm yy
# 3100    46.67   Standard  Atliq Exotica    Luxury     Mumbai  22-Jun
# 3101    60.00   Standard     Atliq City  Business  Hyderabad  22-Jun
# 3102    60.00   Standard      Atliq Bay    Luxury  Bangalore  22-Jun

# %%
df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values()
# Out:
# city
# Bangalore    55.95
# Hyderabad    57.69
# Mumbai       57.79
# Delhi        61.46
# Name: occ_pct, dtype: float64

# %%
df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=True)
# Out:
# city
# Bangalore    55.95
# Hyderabad    57.69
# Mumbai       57.79
# Delhi        61.46
# Name: occ_pct, dtype: float64

# %%
df_august = pd.read_csv(r"C:\Users\pawar\Downloads\new_data_august.csv")
df_august
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  22-Aug    W 32  weekeday                   30        30
# 1     01-Aug-22  22-Aug    W 32  weekeday                   21        30
# 2     01-Aug-22  22-Aug    W 32  weekeday                   23        30
# ...

# %%
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  22-Aug    W 32  weekeday                   30        30
# 1     01-Aug-22  22-Aug    W 32  weekeday                   21        30
# 2     01-Aug-22  22-Aug    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'mmm yy'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (9200, 11)

# %%
latest_df = pd.concat([df, df_august], ignore_index=True, axis=0)
latest_df.tail(10)
# Out:
#       property_id        check_in_date room_category  successful_bookings  \
# 9197        17558  2022-07-31 00:00:00           RT4                    3
# 9198        19563  2022-07-31 00:00:00           RT4                    3
# 9199        17561  2022-07-31 00:00:00           RT4                    3
# 9200        16559            01-Aug-22           RT1                   30
# 9201        19562            01-Aug-22           RT1                   21
# 9202        19563            01-Aug-22           RT1                   23
# 9203        19558            01-Aug-22           RT1                   30
# 9204        19560            01-Aug-22           RT1                   20
# 9205        17561            01-Aug-22           RT1                   18
# 9206        17564            01-Aug-22           RT1                   10
#
#       capacity  occ_pct    room_class  property_name  category       city  \
# 9197       6.0     50.0  Presidential   Atliq Grands    Luxury     Mumbai
# ...

# %%
latest_df.shape
# Out:
# (9207, 14)

# %% [markdown]
# **Print revenue realized per city**

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2027-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558   1930-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558   2028-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558   2028-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on="property_id")
df_bookings_all
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2027-04-22      1/5/2022
# 1        May012216558RT12        16558   1930-04-22      1/5/2022
# 2        May012216558RT13        16558   2028-04-22      1/5/2022
# 3        May012216558RT14        16558   2028-04-22      1/5/2022
# 4        May012216558RT15        16558   2027-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2029-07-22    1931-07-22
# 134586   Jul312217564RT47        17564   1930-07-22    1931-07-22
# 134587   Jul312217564RT48        17564   1930-07-22    1931-07-22
# 134588   Jul312217564RT49        17564   2029-07-22    1931-07-22
# 134589  Jul312217564RT410        17564   1931-07-22    1931-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2027-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558   1930-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558   2028-04-22      1/5/2022      4/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2027-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558   1930-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558   2028-04-22      1/5/2022      4/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2            9100000              9100  Atliq Grands   Luxury  Delhi

# %%
df_date["mmm yy"].unique()
# Out:
# array(['22-May', '22-Jun', '22-Jul'], dtype=object)

# %%
df_date.head(3)
# Out:
#    date  mmm yy week no  day_type
# 0  date  22-May    W 19   weekend
# 1  date  22-May    W 19  weekeday
# 2  date  22-May    W 19  weekeday

# %%
pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  property_name      134590 non-null  object
#  13  category           134590 non-null  object
#  14  city               134590 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
import pandas as pd

# %%
# Convert check_in_date to datetime
df["check_in_date"] = pd.to_datetime(df["check_in_date"], format="%d-%b-%y")

# Make month-year key
df["mmm yy"] = df["check_in_date"].dt.strftime("%y-%b")

# Merge using month-year
final_df = pd.merge(df, df_date, on="mmm yy", how="left")

final_df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25      30.0
# 1        16559    2022-05-01           RT1                   25      30.0
# 2        16559    2022-05-01           RT1                   25      30.0
# 3        16559    2022-05-01           RT1                   25      30.0
# 4        16559    2022-05-01           RT1                   25      30.0
#
#    occ_pct room_class  property_name category    city  mmm yy  date week no  \
# 0    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 1    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 2    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 3    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
# 4    83.33   Standard  Atliq Exotica   Luxury  Mumbai  22-May  date    W 19
#
#    day_type
# 0   weekend
# 1  weekeday
# 2  weekeday
# ...

# %%
df.head(5)
df_date.head(5)
# Out:
#    date  mmm yy week no  day_type
# 0  date  22-May    W 19   weekend
# 1  date  22-May    W 19  weekeday
# 2  date  22-May    W 19  weekeday
# 3  date  22-May    W 19  weekeday
# 4  date  22-May    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"].unique()
# Out:
# array(['date'], dtype=object)

# %%
df_date.columns
# Out:
# Index(['date', 'mmm yy', 'week no', 'day_type'], dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['property_id', 'check_in_date', 'room_category', 'successful_bookings', 'capacity', 'occ_pct', 'room_class', 'property_name', 'category', 'city', 'mmm yy']

# %%
print(df['check_in_date'])
# Out:
# 0      2022-05-01
# 1      2022-05-01
# 2      2022-05-01
# 3      2022-05-01
# 4      2022-05-01
#           ...
# 9195   2022-07-31
# 9196   2022-07-31
# 9197   2022-07-31
# 9198   2022-07-31
# 9199   2022-07-31
# Name: check_in_date, Length: 9200, dtype: datetime64[ns]

# %%
print(df.head())
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25      30.0
# 1        19562    2022-05-01           RT1                   28      30.0
# 2        19563    2022-05-01           RT1                   23      30.0
# 3        17558    2022-05-01           RT1                   30      19.0
# 4        16558    2022-05-01           RT1                   18      19.0
#
#    occ_pct room_class  property_name  category       city  mmm yy  week_no
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai  22-May       17
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore  22-May       17
# 2    76.67   Standard   Atliq Palace  Business  Bangalore  22-May       17
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai  22-May       17
# 4    94.74   Standard   Atliq Grands    Luxury      Delhi  22-May       17

# %%
print(df.dtypes)
# Out:
# property_id                     int64
# check_in_date          datetime64[ns]
# room_category                  object
# successful_bookings             int64
# capacity                      float64
# occ_pct                       float64
# room_class                     object
# property_name                  object
# category                       object
# city                           object
# mmm yy                         object
# week_no                        UInt32
# dtype: object

# %%
df_bookings_all = pd.merge(
    df_bookings_all,
    df_date,
    left_on="check_in_date",   # <-- update this
    right_on="date"
)

# %%
df_bookings_all = df_bookings_all.rename(columns={"chenk_in_date": "check_in_date"})

# %%
df_bookings_all = pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")

# %%
df_bookings_all.columns
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized', 'property_name', 'category', 'city', 'date_x',
#        'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y',
#        'week no_y', 'day_type_y'],
#       dtype='object')

# %%
set(df_bookings_all["check_in_date"]).intersection(set(df_date["date"]))
# Out:
# set()

# %%
print(df_bookings_all["check_in_date"].dtype)
print(df_date["date"].dtype)
# Out:
# object
# object

# %%
print(df_bookings_all["check_in_date"].isin(df_date["date"]).sum())
# Out:
# 0
